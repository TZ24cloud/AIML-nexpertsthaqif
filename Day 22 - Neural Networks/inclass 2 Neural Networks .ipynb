# %% [markdown]
# ## **2. Forward Propagation**

# %% [markdown]
# ## **3. Caculate the Loss**

# %% [markdown]
# ## **4. Back Propagation**

# %% [markdown]
# ## **5. Optimization - Weight Update - Gradient Decent**

# %% [markdown]
# ## **6. Repeat (Epochs)**
