# %% [markdown]
# # $$Automation$$

# %% [markdown]
# - As humans, everyday work sometimes become repetitive
# -
# - Automation -> Process of creating a workflow that performs tasks automatically
#     - e.g. Manufacturing Process were fully Manual. Example - Car manufacturing
#         - Plan and chart out a vehicle
#         - Bring raw mateiral
#         - shape the raw material
#         - assemble
#         - quality checks
#         -
#         - Enter ROBOTS/ assembly lines
#         -
#         - Manufacturing got automated
#         - You designed a machine that could build a car - Workflow into the machine
#         - You pass in raw material, machine gives you a car
#         - What used to be done manually, now runs without supervision
#
#     - Our focus is on tasks we perform on our PCs
#     - Automation is the process of creating workflows perform tasks automatically, remvoing the requirement of manual intervention
#     - We create these workflows using Programs
#     -
#     - if else loops -- python --
#     - if I recieved an email (specific email), notify me on text
#     - We want to broadcast a message in a group of people -- when we recive a certain message --
#     - `if the message contains words == "emergency meeting",
#         - broadcast a message
#         - else:
#            -  pass`

# %% [markdown]
# Used to be in hands of people, who were very **skilled at coding**
# - Interacting with different software, and doing tasks
# - The toughest part ---> interacting with different software
#     - ..
# - Then came in some NO CODE or Low Code tools
#     - made the barrier to automating proccesses a little lesser
#     -
#
# - ZAPIER - good for beginners
# - Make - make.com - Full visual control of your workflows, advanced logic, no code and many integrations
# - n8n - more flexibility, use coding as well - You can self-host n8n
#     - you can run n8n for free, and it will provide privacy as well
#     - bigger learning curve
#     - Please spend time later in exploring and using n8n

# %% [markdown]
# A webhook is a method of enabling communication between web-based applications through custom callbacks.
# - Unlike traditional systems where one system continuously polls another for data, webhooks allow the observer to push data to the subject's system automatically whenever an event occurs.
#
#
# Webhooks follow a simple pattern:
#
# 1. You provide a URL — Your application exposes an HTTP endpoint (the "webhook URL") that can receive POST requests
# 2. An event occurs — Something happens in the source application (payment received, form submitted, file uploaded)
# 3. Data is pushed to you — The source application sends an HTTP POST request to your URL with event data as JSON

# %% [markdown]
# A Scenario - Workflow -
#  - Repetitive in a normal day
#
# - TRIGGER
#     - when does an event start
#     - By a human
#     - Non human - Robot, Agent
#     - e.g. when i recieve a message
#     - when the time is 10:00PM
#     - Manually triggered
# - A workflow, in which trieggerr occurs on its own ---> Automation
#
# - ACTION
#     - What happens next. e.g create a new row in a sheet, or send a message into slack, discord, telegram
#
# - CONNECTION - how to link the tool to an external APP like Google/ outlook using OAuth
# - SCHEDULE - your workflow must work ater a certain period of time.

# %% [markdown]
# SCENARIO:
# - Context: we run a small business and we collect orders using a google form
#     - QR codes, people scan --> google form --> order details
#     - you recieve a message in a **Telegram** OR **Discord**
#         - You can use whatapp business or email as well
# - Goal: When a used creates an order, add the order details in a google sheet, send a notification in the kitchen group
# - Plan:
#     - take a google form - connect it with orders form
#     - fetch order details and paste in a sheet
#     - send details to the kitchen staff
